# %% [markdown]
# ###Build Data Pipeline using Open weather data

# %%
#import libraries
import json
import requests
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
api.key= 'api_kk'
city= "Tampere,FI"

url= f"http://api.openweathermap.org/data/2.5/forecast?q={city}&cnt=240&appid={api.key}"
response=requests.get(url)

# %%
#Extract the data
data=response.json()
json_str= json.dumps(data,indent=4)
print(json_str)
# Out:
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1742007600,
#             "main": {
#                 "temp": 268.17,
#                 "feels_like": 262.37,
#                 "temp_min": 268.17,
#                 "temp_max": 269.72,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 994,
#                 "humidity": 86,
#                 "temp_kf": -1.55
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 14
#             },
#             "wind": {
#                 "speed": 4.48,
#                 "deg": 242,
#                 "gust": 13.92
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-15 03:00:00"
#         },
#         {
#             "dt": 1742018400,
#             "main": {
#                 "temp": 270.36,
#                 "feels_like": 264.16,
#                 "temp_min": 270.36,
#                 "temp_max": 271.84,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 994,
#                 "humidity": 77,
#                 "temp_kf": -1.48
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 34
#             },
#             "wind": {
#                 "speed": 6,
#                 "deg": 243,
#                 "gust": 15.23
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-15 06:00:00"
#         },
#         {
#             "dt": 1742029200,
#             "main": {
#                 "temp": 275.71,
#                 "feels_like": 270.45,
#                 "temp_min": 275.71,
#                 "temp_max": 275.71,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "grnd_level": 993,
#                 "humidity": 60,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 67
#             },
#             "wind": {
#                 "speed": 7.2,
#                 "deg": 247,
#                 "gust": 16.61
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-15 09:00:00"
#         },
#         {
#             "dt": 1742040000,
#             "main": {
#                 "temp": 276.12,
#                 "feels_like": 270.9,
#                 "temp_min": 276.12,
#                 "temp_max": 276.12,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "grnd_level": 992,
#                 "humidity": 53,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 7.41,
#                 "deg": 248,
#                 "gust": 15.32
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-15 12:00:00"
#         },
#         {
#             "dt": 1742050800,
#             "main": {
#                 "temp": 274.46,
#                 "feels_like": 268.76,
#                 "temp_min": 274.46,
#                 "temp_max": 274.46,
#                 "pressure": 1005,
#                 "sea_level": 1005,
#                 "grnd_level": 990,
#                 "humidity": 60,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 7.39,
#                 "deg": 245,
#                 "gust": 15.39
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-15 15:00:00"
#         },
#         {
#             "dt": 1742061600,
#             "main": {
#                 "temp": 274.15,
#                 "feels_like": 268.66,
#                 "temp_min": 274.15,
#                 "temp_max": 274.15,
#                 "pressure": 1003,
#                 "sea_level": 1003,
#                 "grnd_level": 988,
#                 "humidity": 65,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.68,
#                 "deg": 240,
#                 "gust": 15.12
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-15 18:00:00"
#         },
#         {
#             "dt": 1742072400,
#             "main": {
#                 "temp": 273.06,
#                 "feels_like": 267.28,
#                 "temp_min": 273.06,
#                 "temp_max": 273.06,
#                 "pressure": 1000,
#                 "sea_level": 1000,
#                 "grnd_level": 985,
#                 "humidity": 95,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 600,
#                     "main": "Snow",
#                     "description": "light snow",
#                     "icon": "13n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.65,
#                 "deg": 240,
#                 "gust": 16.5
#             },
#             "visibility": 125,
#             "pop": 0.75,
#             "snow": {
#                 "3h": 0.34
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-15 21:00:00"
#         },
#         {
#             "dt": 1742083200,
#             "main": {
#                 "temp": 273.41,
#                 "feels_like": 268.49,
#                 "temp_min": 273.41,
#                 "temp_max": 273.41,
#                 "pressure": 999,
#                 "sea_level": 999,
#                 "grnd_level": 984,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 601,
#                     "main": "Snow",
#                     "description": "snow",
#                     "icon": "13n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.12,
#                 "deg": 326,
#                 "gust": 10.74
#             },
#             "visibility": 3577,
#             "pop": 1,
#             "snow": {
#                 "3h": 2.83
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-16 00:00:00"
#         },
#         {
#             "dt": 1742094000,
#             "main": {
#                 "temp": 268.71,
#                 "feels_like": 262.85,
#                 "temp_min": 268.71,
#                 "temp_max": 268.71,
#                 "pressure": 1004,
#                 "sea_level": 1004,
#                 "grnd_level": 988,
#                 "humidity": 68,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 600,
#                     "main": "Snow",
#                     "description": "light snow",
#                     "icon": "13n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 4.75,
#                 "deg": 326,
#                 "gust": 11.99
#             },
#             "visibility": 10000,
#             "pop": 0.32,
#             "snow": {
#                 "3h": 0.26
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-16 03:00:00"
#         },
#         {
#             "dt": 1742104800,
#             "main": {
#                 "temp": 268.15,
#                 "feels_like": 262,
#                 "temp_min": 268.15,
#                 "temp_max": 268.15,
#                 "pressure": 1006,
#                 "sea_level": 1006,
#                 "grnd_level": 990,
#                 "humidity": 74,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 55
#             },
#             "wind": {
#                 "speed": 4.97,
#                 "deg": 306,
#                 "gust": 11.19
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-16 06:00:00"
#         },
#         {
#             "dt": 1742115600,
#             "main": {
#                 "temp": 270.87,
#                 "feels_like": 265,
#                 "temp_min": 270.87,
#                 "temp_max": 270.87,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "grnd_level": 992,
#                 "humidity": 62,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 5
#             },
#             "wind": {
#                 "speed": 5.65,
#                 "deg": 317,
#                 "gust": 9.92
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-16 09:00:00"
#         },
#         {
#             "dt": 1742126400,
#             "main": {
#                 "temp": 271.52,
#                 "feels_like": 265.24,
#                 "temp_min": 271.52,
#                 "temp_max": 271.52,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 994,
#                 "humidity": 61,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 600,
#                     "main": "Snow",
#                     "description": "light snow",
#                     "icon": "13d"
#                 }
#             ],
#             "clouds": {
#                 "all": 7
#             },
#             "wind": {
#                 "speed": 6.79,
#                 "deg": 328,
#                 "gust": 14.35
#             },
#             "visibility": 10000,
#             "pop": 0.2,
#             "snow": {
#                 "3h": 0.12
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-16 12:00:00"
#         },
#         {
#             "dt": 1742137200,
#             "main": {
#                 "temp": 269.93,
#                 "feels_like": 263.49,
#                 "temp_min": 269.93,
#                 "temp_max": 269.93,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 997,
#                 "humidity": 65,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 600,
#                     "main": "Snow",
#                     "description": "light snow",
#                     "icon": "13d"
#                 }
#             ],
#             "clouds": {
#                 "all": 41
#             },
#             "wind": {
#                 "speed": 6.23,
#                 "deg": 343,
#                 "gust": 13.75
#             },
#             "visibility": 10000,
#             "pop": 0.2,
#             "snow": {
#                 "3h": 0.12
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-16 15:00:00"
#         },
#         {
#             "dt": 1742148000,
#             "main": {
#                 "temp": 268.07,
#                 "feels_like": 261.95,
#                 "temp_min": 268.07,
#                 "temp_max": 268.07,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 1001,
#                 "humidity": 73,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 24
#             },
#             "wind": {
#                 "speed": 4.9,
#                 "deg": 337,
#                 "gust": 12.88
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-16 18:00:00"
#         },
#         {
#             "dt": 1742158800,
#             "main": {
#                 "temp": 267.31,
#                 "feels_like": 262.1,
#                 "temp_min": 267.31,
#                 "temp_max": 267.31,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "grnd_level": 1003,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 3.54,
#                 "deg": 320,
#                 "gust": 12.92
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-16 21:00:00"
#         },
#         {
#             "dt": 1742169600,
#             "main": {
#                 "temp": 266.97,
#                 "feels_like": 261.44,
#                 "temp_min": 266.97,
#                 "temp_max": 266.97,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "grnd_level": 1004,
#                 "humidity": 83,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 2
#             },
#             "wind": {
#                 "speed": 3.81,
#                 "deg": 306,
#                 "gust": 11.77
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-17 00:00:00"
#         },
#         {
#             "dt": 1742180400,
#             "main": {
#                 "temp": 266.32,
#                 "feels_like": 261.89,
#                 "temp_min": 266.32,
#                 "temp_max": 266.32,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "grnd_level": 1004,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 12
#             },
#             "wind": {
#                 "speed": 2.62,
#                 "deg": 289,
#                 "gust": 9.09
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-17 03:00:00"
#         },
#         {
#             "dt": 1742191200,
#             "main": {
#                 "temp": 267.93,
#                 "feels_like": 263.13,
#                 "temp_min": 267.93,
#                 "temp_max": 267.93,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "grnd_level": 1004,
#                 "humidity": 82,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": {
#                 "all": 22
#             },
#             "wind": {
#                 "speed": 3.25,
#                 "deg": 285,
#                 "gust": 11.24
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-17 06:00:00"
#         },
#         {
#             "dt": 1742202000,
#             "main": {
#                 "temp": 272.77,
#                 "feels_like": 267.94,
#                 "temp_min": 272.77,
#                 "temp_max": 272.77,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "grnd_level": 1003,
#                 "humidity": 64,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 26
#             },
#             "wind": {
#                 "speed": 4.7,
#                 "deg": 289,
#                 "gust": 7.91
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-17 09:00:00"
#         },
#         {
#             "dt": 1742212800,
#             "main": {
#                 "temp": 273.6,
#                 "feels_like": 269.24,
#                 "temp_min": 273.6,
#                 "temp_max": 273.6,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 1003,
#                 "humidity": 70,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 62
#             },
#             "wind": {
#                 "speed": 4.27,
#                 "deg": 289,
#                 "gust": 7.73
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-17 12:00:00"
#         },
#         {
#             "dt": 1742223600,
#             "main": {
#                 "temp": 272.62,
#                 "feels_like": 268.06,
#                 "temp_min": 272.62,
#                 "temp_max": 272.62,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 1001,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 4.22,
#                 "deg": 265,
#                 "gust": 8.91
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-17 15:00:00"
#         },
#         {
#             "dt": 1742234400,
#             "main": {
#                 "temp": 272.01,
#                 "feels_like": 266.81,
#                 "temp_min": 272.01,
#                 "temp_max": 272.01,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 999,
#                 "humidity": 86,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5,
#                 "deg": 256,
#                 "gust": 12.4
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-17 18:00:00"
#         },
#         {
#             "dt": 1742245200,
#             "main": {
#                 "temp": 272.51,
#                 "feels_like": 266.83,
#                 "temp_min": 272.51,
#                 "temp_max": 272.51,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 996,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 600,
#                     "main": "Snow",
#                     "description": "light snow",
#                     "icon": "13n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.11,
#                 "deg": 257,
#                 "gust": 14.17
#             },
#             "visibility": 709,
#             "pop": 0.43,
#             "snow": {
#                 "3h": 0.24
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-17 21:00:00"
#         },
#         {
#             "dt": 1742256000,
#             "main": {
#                 "temp": 274.32,
#                 "feels_like": 269.49,
#                 "temp_min": 274.32,
#                 "temp_max": 274.32,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 994,
#                 "humidity": 89,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.38,
#                 "deg": 281,
#                 "gust": 13
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-18 00:00:00"
#         },
#         {
#             "dt": 1742266800,
#             "main": {
#                 "temp": 275.44,
#                 "feels_like": 270.77,
#                 "temp_min": 275.44,
#                 "temp_max": 275.44,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 994,
#                 "humidity": 86,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.65,
#                 "deg": 292,
#                 "gust": 12.51
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-18 03:00:00"
#         },
#         {
#             "dt": 1742277600,
#             "main": {
#                 "temp": 275.94,
#                 "feels_like": 271.3,
#                 "temp_min": 275.94,
#                 "temp_max": 275.94,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 995,
#                 "humidity": 85,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 98
#             },
#             "wind": {
#                 "speed": 5.87,
#                 "deg": 297,
#                 "gust": 13.41
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-18 06:00:00"
#         },
#         {
#             "dt": 1742288400,
#             "main": {
#                 "temp": 277.36,
#                 "feels_like": 273.24,
#                 "temp_min": 277.36,
#                 "temp_max": 277.36,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 995,
#                 "humidity": 82,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.55,
#                 "deg": 289,
#                 "gust": 13
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-18 09:00:00"
#         },
#         {
#             "dt": 1742299200,
#             "main": {
#                 "temp": 278.27,
#                 "feels_like": 274.36,
#                 "temp_min": 278.27,
#                 "temp_max": 278.27,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 996,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 5.62,
#                 "deg": 290,
#                 "gust": 11.86
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-18 12:00:00"
#         },
#         {
#             "dt": 1742310000,
#             "main": {
#                 "temp": 277.4,
#                 "feels_like": 273.33,
#                 "temp_min": 277.4,
#                 "temp_max": 277.4,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 997,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 82
#             },
#             "wind": {
#                 "speed": 5.46,
#                 "deg": 283,
#                 "gust": 11.56
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-18 15:00:00"
#         },
#         {
#             "dt": 1742320800,
#             "main": {
#                 "temp": 274.93,
#                 "feels_like": 270.49,
#                 "temp_min": 274.93,
#                 "temp_max": 274.93,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 998,
#                 "humidity": 87,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 80
#             },
#             "wind": {
#                 "speed": 4.95,
#                 "deg": 267,
#                 "gust": 13.41
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-18 18:00:00"
#         },
#         {
#             "dt": 1742331600,
#             "main": {
#                 "temp": 275.97,
#                 "feels_like": 271.31,
#                 "temp_min": 275.97,
#                 "temp_max": 275.97,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 998,
#                 "humidity": 83,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 90
#             },
#             "wind": {
#                 "speed": 5.94,
#                 "deg": 273,
#                 "gust": 13.9
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-18 21:00:00"
#         },
#         {
#             "dt": 1742342400,
#             "main": {
#                 "temp": 275.47,
#                 "feels_like": 270.52,
#                 "temp_min": 275.47,
#                 "temp_max": 275.47,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 998,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 81
#             },
#             "wind": {
#                 "speed": 6.27,
#                 "deg": 270,
#                 "gust": 15.51
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-19 00:00:00"
#         },
#         {
#             "dt": 1742353200,
#             "main": {
#                 "temp": 276.35,
#                 "feels_like": 271.49,
#                 "temp_min": 276.35,
#                 "temp_max": 276.35,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 997,
#                 "humidity": 76,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 6.65,
#                 "deg": 270,
#                 "gust": 15.39
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-19 03:00:00"
#         },
#         {
#             "dt": 1742364000,
#             "main": {
#                 "temp": 276.23,
#                 "feels_like": 271.21,
#                 "temp_min": 276.23,
#                 "temp_max": 276.23,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 998,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 87
#             },
#             "wind": {
#                 "speed": 6.95,
#                 "deg": 269,
#                 "gust": 14.88
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-19 06:00:00"
#         },
#         {
#             "dt": 1742374800,
#             "main": {
#                 "temp": 278.27,
#                 "feels_like": 273.82,
#                 "temp_min": 278.27,
#                 "temp_max": 278.27,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 999,
#                 "humidity": 77,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 34
#             },
#             "wind": {
#                 "speed": 7,
#                 "deg": 283,
#                 "gust": 14.54
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-19 09:00:00"
#         },
#         {
#             "dt": 1742385600,
#             "main": {
#                 "temp": 279.17,
#                 "feels_like": 275.29,
#                 "temp_min": 279.17,
#                 "temp_max": 279.17,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "grnd_level": 1001,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 35
#             },
#             "wind": {
#                 "speed": 6.13,
#                 "deg": 292,
#                 "gust": 12.83
#             },
#             "visibility": 10000,
#             "pop": 0.2,
#             "rain": {
#                 "3h": 0.12
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-19 12:00:00"
#         },
#         {
#             "dt": 1742396400,
#             "main": {
#                 "temp": 277.35,
#                 "feels_like": 273.65,
#                 "temp_min": 277.35,
#                 "temp_max": 277.35,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 1003,
#                 "humidity": 77,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 30
#             },
#             "wind": {
#                 "speed": 4.67,
#                 "deg": 303,
#                 "gust": 10.54
#             },
#             "visibility": 10000,
#             "pop": 0.2,
#             "rain": {
#                 "3h": 0.25
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-03-19 15:00:00"
#         },
#         {
#             "dt": 1742407200,
#             "main": {
#                 "temp": 273.24,
#                 "feels_like": 270.65,
#                 "temp_min": 273.24,
#                 "temp_max": 273.24,
#                 "pressure": 1021,
#                 "sea_level": 1021,
#                 "grnd_level": 1006,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 37
#             },
#             "wind": {
#                 "speed": 2.12,
#                 "deg": 277,
#                 "gust": 5.68
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-19 18:00:00"
#         },
#         {
#             "dt": 1742418000,
#             "main": {
#                 "temp": 272.33,
#                 "feels_like": 269.74,
#                 "temp_min": 272.33,
#                 "temp_max": 272.33,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "grnd_level": 1007,
#                 "humidity": 97,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 75
#             },
#             "wind": {
#                 "speed": 2,
#                 "deg": 271,
#                 "gust": 5.82
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-19 21:00:00"
#         },
#         {
#             "dt": 1742428800,
#             "main": {
#                 "temp": 272.39,
#                 "feels_like": 270.15,
#                 "temp_min": 272.39,
#                 "temp_max": 272.39,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 1008,
#                 "humidity": 97,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 88
#             },
#             "wind": {
#                 "speed": 1.75,
#                 "deg": 264,
#                 "gust": 4.46
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-03-20 00:00:00"
#         }
#     ],
#     "city": {
#         "id": 634963,
#         "name": "Tampere",
#         "coord": {
#             "lat": 61.4991,
#             "lon": 23.7871
#         },
#         "country": "FI",
#         "population": 0,
#         "timezone": 7200,
#         "sunrise": 1742013737,
#         "sunset": 1742055922
#     }
# }

# %% [markdown]
# ##TRANSFORMATION FROM JSON TO DATAFRAME

# %%
#convert temperature from kelvin to celsuis

def kelvin_to_celsius(temp_k):
    return temp_k - 273.15

# %%
if response.status_code == 200:
    data = response.json()
     # Check if 'list' key is present
    if 'list' not in data:
        print("Error: 'list' key missing in API response.")
        print(data)  # Print full response for debugging
    else:
        weather_data = []

    for hour in data['list']:
        date_time = datetime.utcfromtimestamp(hour['dt']).strftime('%Y-%m-%d %H:%M:%S')
        temp = kelvin_to_celsius(hour['main']['temp'])
        feels_like = kelvin_to_celsius(hour['main']['feels_like'])
        pressure = hour['main']['pressure']
        humidity = hour['main']['humidity']
        wind_speed = hour['wind']['speed']
        wind_direction = hour['wind']['deg']
        cloudiness = hour['clouds']['all']
        weather_main = hour['weather'][0]['main']
        weather_description = hour['weather'][0]['description']
        rain_volume = hour.get('rain', {}).get('3h', 0)
        snow_volume = hour.get('snow', {}).get('3h', 0)

   
        weather_data.append({
            "DateTime": date_time,
            "Temperature": temp,
            "Feels Like_temp" : feels_like,
            "Pressure(hPa)" : pressure,
            "Humidity_percent" : humidity,
            "Weather" : weather_main,
            "Weather Description" : weather_description,
            "Wind Speed": wind_speed,
            "Wind Direction": wind_direction,
            "Cloudiness": cloudiness,
            "Rain Volume(mm)": rain_volume,
            "Snow Volume(mm)": snow_volume
        })
        df = pd.DataFrame(weather_data)
else:
    prrint(f"Failed to get data : {response.status_code}")

df.head()
# Out:
#               DateTime  Temperature  Feels Like_temp  Pressure(hPa)  \
# 0  2025-03-15 03:00:00        -4.98           -10.78           1009
# 1  2025-03-15 06:00:00        -2.79            -8.99           1009
# 2  2025-03-15 09:00:00         2.56            -2.70           1008
# 3  2025-03-15 12:00:00         2.97            -2.25           1007
# 4  2025-03-15 15:00:00         1.31            -4.39           1005
#
#    Humidity_percent Weather Weather Description  Wind Speed  Wind Direction  \
# 0                86  Clouds          few clouds        4.48             242
# 1                77  Clouds    scattered clouds        6.00             243
# 2                60  Clouds       broken clouds        7.20             247
# 3                53  Clouds       broken clouds        7.41             248
# 4                60  Clouds     overcast clouds        7.39             245
#
#    Cloudiness  Rain Volume(mm)  Snow Volume(mm)
# 0          14              0.0              0.0
# 1          34              0.0              0.0
# 2          67              0.0              0.0
# 3          83              0.0              0.0
# 4         100              0.0              0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DateTime             40 non-null     object
#  1   Temperature          40 non-null     float64
#  2   Feels Like_temp      40 non-null     float64
#  3   Pressure(hPa)        40 non-null     int64
#  4   Humidity_percent     40 non-null     int64
#  5   Weather              40 non-null     object
#  6   Weather Description  40 non-null     object
#  7   Wind Speed           40 non-null     float64
#  8   Wind Direction       40 non-null     int64
#  9   Cloudiness           40 non-null     int64
#  10  Rain Volume(mm)      40 non-null     float64
#  11  Snow Volume(mm)      40 non-null     float64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 3.9+ KB

# %% [markdown]
# LOADING OF THE DATA INTO POSTGRESQL DATABASE

# %%
import psycopg2 # for connecting to postgresql
from sqlalchemy import create_engine #tof efficiently reuse the connection

# %%
db_username = 'postgres'
db_password = 'PASSWORD'
db_host = 'localhost'
db_port = 5432
db_name = 'postgres'

# %%
import urllib.parse
encoded_password = urllib.parse.quote(db_password)
engine = create_engine(f'postgresql://{db_username}:{encoded_password}@{db_host}:{db_port}/{db_name}')

# %%
table_name = 'weather_data'

df.to_sql(table_name, engine, if_exists='replace', index=False)

engine.dispose()
